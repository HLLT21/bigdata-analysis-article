# %% [markdown]
# # 1유형 6번

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ds/p210303.csv')
df
# Out:
#           country iso2 iso3  iso_numeric g_whoregion  year  new_sp  new_sn  \
# 0     Afghanistan   AF  AFG            4         EMR  1980     NaN     NaN
# 1     Afghanistan   AF  AFG            4         EMR  1981     NaN     NaN
# 2     Afghanistan   AF  AFG            4         EMR  1982     NaN     NaN
# 3     Afghanistan   AF  AFG            4         EMR  1983     NaN     NaN
# 4     Afghanistan   AF  AFG            4         EMR  1984     NaN     NaN
# ...           ...  ...  ...          ...         ...   ...     ...     ...
# 8702     Zimbabwe   ZW  ZWE          716         AFR  2016     NaN     NaN
# 8703     Zimbabwe   ZW  ZWE          716         AFR  2017     NaN     NaN
# 8704     Zimbabwe   ZW  ZWE          716         AFR  2018     NaN     NaN
# 8705     Zimbabwe   ZW  ZWE          716         AFR  2019     NaN     NaN
# 8706     Zimbabwe   ZW  ZWE          716         AFR  2020     NaN     NaN
#
# ...

# %%
df = df[['country', 'year', 'new_sp']].dropna()

# %%
mean = df[df['year'] == 2000]['new_sp'].mean()
mean
# Out:
# 7865.341836734694

# %%
country = df[(df['year'] == 2000) & (df['new_sp'] >= mean)]
country
# Out:
#                                     country  year    new_sp
# 102                                 Algeria  2000    8328.0
# 225                                  Angola  2000    9053.0
# 676                              Bangladesh  2000   38484.0
# 1127                                 Brazil  2000   41186.0
# 1414                               Cambodia  2000   14822.0
# 1701                                  China  2000  204765.0
# 1824                               Colombia  2000    8358.0
# 2029                          Côte d'Ivoire  2000   10276.0
# 2245  Democratic People's Republic of Korea  2000   16440.0
# 2286       Democratic Republic of the Congo  2000   36513.0
# 2778                               Ethiopia  2000   30510.0
# 3680                                  India  2000  349374.0
# 3721                              Indonesia  2000   52338.0
# 4008                                  Japan  2000   11853.0
# 4090                             Kazakhstan  2000    8903.0
# ...

# %%
len(country['country'].value_counts())
# Out:
# 38
